# %% [markdown]
# # Hadoop Cluster and MapReduce — Lab Runbook
#
# > Notebook-style runbook reconstructed from the original lab document. Original document remains preserved in the repository.

# %% [markdown]
# Successfully installed Cent OS7 on four virtual machines.

# %% [markdown]
# ### Evidence 1
# ![Lab evidence](attachment:evidence-1.jpg)

# %% [markdown]
# Successfully pinged each cluster machine from manager node.

# %% [markdown]
# ### Evidence 2
# ![Lab evidence](attachment:evidence-2.jpg)

# %% [markdown]
# Successfully logged into cluster via Putty

# %% [markdown]
# ### Evidence 3
# ![Lab evidence](attachment:evidence-3.jpg)

# %% [markdown]
# Succesfully updated OS on each cluster machine

# %% [markdown]
# ### Evidence 4
# ![Lab evidence](attachment:evidence-4.jpg)

# %% [markdown]
# Succesfully installed nano

# %% [markdown]
# ### Evidence 5
# ![Lab evidence](attachment:evidence-5.jpg)

# %% [markdown]
# Successfully installed java

# %% [markdown]
# ### Evidence 6
# ![Lab evidence](attachment:evidence-6.jpg)

# %% [markdown]
# Successfully edited the /etc/hosts entries for manager node

# %% [markdown]
# ### Evidence 7
# ![Lab evidence](attachment:evidence-7.jpg)

# %% [markdown]
# Succesfully ssh’d into worker1, worker2, worker3 nodes from manager node

# %% [markdown]
# ### Evidence 8
# ![Lab evidence](attachment:evidence-8.jpg)

# %% [markdown]
# Succesfully added Hadoop username and password to each node

# %% [markdown]
# ### Evidence 9
# ![Lab evidence](attachment:evidence-9.jpg)

# %% [markdown]
# Succesfully formatted name node

# %% [markdown]
# ### Evidence 10
# ![Lab evidence](attachment:evidence-10.jpg)

# %% [markdown]
# Succesfully checked Java processes for Hadoop map reduce :

# %% [markdown]
# ### Evidence 11
# ![Lab evidence](attachment:evidence-11.jpg)

# %% [markdown]
# Succesfully created directories and executed map reduce job

# %% [markdown]
# ### Evidence 12
# ![Lab evidence](attachment:evidence-12.jpg)

# %% [markdown]
# ### Evidence 13
# ![Lab evidence](attachment:evidence-13.jpg)

# %% [markdown]
# Output of Map reduce:

# %% [markdown]
# ### Evidence 14
# ![Lab evidence](attachment:evidence-14.jpg)

# %% [markdown]
# ### Evidence 15
# ![Lab evidence](attachment:evidence-15.jpg)

# %% [markdown]
# ### Evidence 16
# ![Lab evidence](attachment:evidence-16.jpg)

# %% [markdown]
# ## Modernization Notes
#
# This notebook preserves the historical lab sequence. Before rerunning, validate versions, package repositories, service commands, client shells, and platform-specific paths against current vendor documentation.
